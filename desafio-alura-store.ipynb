# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

# %% [markdown]
# #0. Valores nulos

# %%
lojas = [loja, loja2, loja3, loja4]
nomes = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
dfs_dados = {}

for i in range(len(lojas)):
    dados_nulos = lojas[i].isnull().sum()

    df_dados_nulos = pd.DataFrame({'Dados': dados_nulos.index, 'Quantidades': dados_nulos.values})
    dfs_dados[nomes[i]] = df_dados_nulos

    print(f'{nomes[i]}\n')
    print(f'{df_dados_nulos}\n\n')
# Out:
# Loja 1
#
#                      Dados  Quantidades
# 0                  Produto            0
# 1     Categoria do Produto            0
# 2                    Preço            0
# 3                    Frete            0
# 4           Data da Compra            0
# 5                 Vendedor            0
# 6          Local da compra            0
# 7      Avaliação da compra            0
# 8        Tipo de pagamento            0
# 9   Quantidade de parcelas            0
# 10                     lat            0
# 11                     lon            0
#
#
# Loja 2
#
#                      Dados  Quantidades
# 0                  Produto            0
# 1     Categoria do Produto            0
# 2                    Preço            0
# 3                    Frete            0
# 4           Data da Compra            0
# 5                 Vendedor            0
# 6          Local da compra            0
# 7      Avaliação da compra            0
# 8        Tipo de pagamento            0
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
import matplotlib.pyplot as plt

lojas = [loja, loja2, loja3, loja4]
nomes = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
faturamentos = []
dfs_faturamento = {}


for i in range(len(lojas)):
    faturamento_total = lojas[i]['Preço'].sum()
    faturamentos.append(faturamento_total)

    df_faturamento = pd.DataFrame({'Loja': [nomes[i]], 'Faturamento Total (R$)': [faturamento_total]})
    dfs_faturamento[nomes[i]] = df_faturamento

    print(f'\n{df_faturamento}')
# Out:
#      Loja  Faturamento Total (R$)
# 0  Loja 1              1534509.12
#
#      Loja  Faturamento Total (R$)
# 0  Loja 2              1488459.06
#
#      Loja  Faturamento Total (R$)
# 0  Loja 3              1464025.03
#
#      Loja  Faturamento Total (R$)
# 0  Loja 4              1384497.58

# %% [markdown]
# #1.1. Gráfico do Faturamento

# %%
print(f'\n \n')
plt.figure(figsize=(14,7))
plt.bar(nomes, faturamentos, color='red')
plt.xlabel('Loja', fontsize=15)
plt.ylabel('Faturamento Total (R$)', fontsize=15)
plt.title('Faturamento por Loja', fontsize=25)
plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %%
import matplotlib.pyplot as plt

lojas = [loja, loja2, loja3, loja4]
nomes = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
dfs_categorias = {}

for i in range(len(lojas)):
    produtos_vendidos = lojas[i]['Categoria do Produto'].value_counts()

    df_categorias = pd.DataFrame({'Categoria': produtos_vendidos.index, 'Quantidade': produtos_vendidos.values})

    dfs_categorias[nomes[i]] = df_categorias

    print(f'{nomes[i]}\n')
    print(f'{df_categorias}\n')
    print(f'Vendas totais: {produtos_vendidos.sum()}\n\n')
# Out:
# Loja 1
#
#                Categoria  Quantidade
# 0                 moveis         465
# 1            eletronicos         448
# 2             brinquedos         324
# 3       eletrodomesticos         312
# 4        esporte e lazer         284
# 5  instrumentos musicais         182
# 6                 livros         173
# 7  utilidades domesticas         171
#
# Vendas totais: 2359
#
#
# Loja 2
#
#                Categoria  Quantidade
# 0                 moveis         442
# 1            eletronicos         422
# 2             brinquedos         313
# 3       eletrodomesticos         305
# 4        esporte e lazer         275
# 5  instrumentos musicais         224
# 6                 livros         197
# 7  utilidades domesticas         181
#
# Vendas totais: 2359
#
#
# Loja 3
#
#                Categoria  Quantidade
# 0                 moveis         499
# 1            eletronicos         451
# 2             brinquedos         315
# 3       eletrodomesticos         278
# ...

# %% [markdown]
# #2.1 Gráficos de Venda por Categoria

# %%
for i in range(len(lojas)):
    produtos_vendidos = lojas[i]['Categoria do Produto'].value_counts()

    plt.figure(figsize=(6,6))
    plt.pie(produtos_vendidos, labels=produtos_vendidos.index.str.capitalize(), autopct='%1.2f%%', startangle=90)
    plt.title(f'{nomes[i]} - Vendas Por Categoria')
    plt.show()
    print('\n\n')

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
lojas = [loja, loja2, loja3, loja4]
nomes = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
medias = []
dfs_medias = {}

for i in range(len(lojas)):
    m_avaliacao = round((lojas[i]['Avaliação da compra'].sum()) / (len(lojas[i]['Avaliação da compra'])), 2)
    medias.append(m_avaliacao)

    df_medias = pd.DataFrame({'Loja': [nomes[i]], 'Avaliação Média': [m_avaliacao]})
    dfs_medias[nomes[i]] = df_medias

    print(f'\n{df_medias}')
# Out:
#      Loja  Avaliação Média
# 0  Loja 1             3.98
#
#      Loja  Avaliação Média
# 0  Loja 2             4.04
#
#      Loja  Avaliação Média
# 0  Loja 3             4.05
#
#      Loja  Avaliação Média
# 0  Loja 4              4.0

# %% [markdown]
# #3.1. Gráfico das Médias das Avaliações

# %%
print(f'\n \n')
plt.figure(figsize=(14,7))
plt.plot(nomes, medias, marker='o', linestyle='-', color='red')
plt.xlabel('Loja', fontsize=15)
plt.ylabel('Avaliação Média', fontsize=15)
plt.title('Avaliação Média por Loja', fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# # 4. Produtos Mais Vendidos

# %%
import matplotlib.pyplot as plt

lojas = [loja, loja2, loja3, loja4]
dfs_mais_vendidos = {}

for i in range(len(lojas)):
  mais_vendidos = lojas[i]['Produto'].value_counts().head(10)

  df_mais_vendidos = pd.DataFrame({'Produto': mais_vendidos.index, 'Quantidade': mais_vendidos.values})
  dfs_mais_vendidos[nomes[i]] = df_mais_vendidos

  print(f'Os 10 Produtos MAIS Vendidos - {nomes[i]}\n')
  print(f'{df_mais_vendidos}\n\n\n')
# Out:
# Os 10 Produtos MAIS Vendidos - Loja 1
#
#               Produto  Quantidade
# 0         Micro-ondas          60
# 1       TV Led UHD 4K          60
# 2       Guarda roupas          60
# 3  Secadora de roupas          58
# 4              Cômoda          56
# 5    Blocos de montar          56
# 6    Bola de basquete          55
# 7           Bicicleta          54
# 8        Copo térmico          54
# 9           Geladeira          54
#
#
#
# Os 10 Produtos MAIS Vendidos - Loja 2
#
#                     Produto  Quantidade
# 0  Iniciando em programação          65
# 1               Micro-ondas          62
# 2                   Bateria          61
# 3                    Violão          58
# 4                  Pandeiro          58
# 5        Secadora de roupas          57
# 6          Celular Plus X42          55
# 7          Blocos de montar          54
# 8             Guarda roupas          54
# 9           Jogo de panelas          52
#
#
#
# Os 10 Produtos MAIS Vendidos - Loja 3
#
# ...

# %% [markdown]
# #4.1 Gráfico dos Produtos Mais Vendidos

# %%
for i in range(len(lojas)):
  mais_vendidos = lojas[i]['Produto'].value_counts().head(10)
  plt.figure(figsize=(6,6))
  plt.pie(mais_vendidos, labels=mais_vendidos.index.str.capitalize(), autopct='%1.2f%%', startangle=90)
  plt.title(f'Produtos Mais Vendidos - {nomes[i]}')
  plt.show()
  print('\n\n')

# %% [markdown]
# #5. Produtos Menos Vendidos

# %%
import matplotlib.pyplot as plt

lojas = [loja, loja2, loja3, loja4]
dfs_menos_vendidos = {}

for i in range(len(lojas)):
  menos_vendidos = lojas[i]["Produto"].value_counts().nsmallest(10)

  df_menos_vendidos = pd.DataFrame({'Produto': menos_vendidos.index, 'Quantidade': menos_vendidos.values})
  dfs_menos_vendidos[nomes[i]] = df_menos_vendidos

  print(f'Os 10 Produtos MENOS Vendidos - {nomes[i]}\n')
  print(f'{df_menos_vendidos}\n\n\n')
# Out:
# Os 10 Produtos MENOS Vendidos - Loja 1
#
#                        Produto  Quantidade
# 0                      Headset          33
# 1                 Celular ABXY          33
# 2            Panela de pressão          35
# 3                     Pandeiro          36
# 4                      Mochila          39
# 5  Ciência de dados com python          39
# 6           Assistente virtual          40
# 7                  Boneca bebê          40
# 8               Mesa de jantar          40
# 9               Dinossauro Rex          40
#
#
#
# Os 10 Produtos MENOS Vendidos - Loja 2
#
#               Produto  Quantidade
# 0   Jogo de tabuleiro          32
# 1      Mesa de jantar          34
# 2          Impressora          34
# 3            Poltrona          35
# 4      Fone de ouvido          37
# 5  Assistente virtual          38
# 6            Faqueiro          39
# 7            Smart TV          40
# 8        Celular ABXY          41
# 9    Bola de basquete          42
#
#
#
# ...

# %% [markdown]
# #5.1 Gráfico dos Produtos Menos Vendidos

# %%
for i in range(len(lojas)):
  menos_vendidos = lojas[i]["Produto"].value_counts().nsmallest(10)
  plt.figure(figsize=(6,6))
  plt.pie(menos_vendidos, labels=menos_vendidos.index.str.capitalize(), autopct='%1.2f%%', startangle=90)
  plt.title(f'Produtos Menos Vendidos - {nomes[i]}')
  plt.show()
  print('\n\n')

# %% [markdown]
# # 6. Frete Médio por Loja

# %%
import matplotlib.pyplot as plt

lojas = [loja, loja2, loja3, loja4]
fretes = []
dfs_fretes = {}

for i in range(len(lojas)):
  valor_frete = round(lojas[i]['Frete'].sum() / len(lojas[i]), 2)
  fretes.append(valor_frete)

  df_fretes = pd.DataFrame({'Loja': [nomes[i]], 'Frete Médio (R$)': [valor_frete]})
  dfs_fretes[nomes[i]] = df_fretes

  print(f'{df_fretes}\n')
# Out:
#      Loja  Frete Médio (R$)
# 0  Loja 1             34.69
#
#      Loja  Frete Médio (R$)
# 0  Loja 2             33.62
#
#      Loja  Frete Médio (R$)
# 0  Loja 3             33.07
#
#      Loja  Frete Médio (R$)
# 0  Loja 4             31.28

# %% [markdown]
# #6.1. Gráfico Frete

# %%
plt.figure(figsize=(14,7))
plt.barh(nomes, fretes, color='blue')
plt.xlabel('Valor (R$)', fontsize=15)
plt.ylabel('Loja', fontsize=15)
plt.title('Valor do Médio Frete', fontsize=25)
plt.show()

# %% [markdown]
# #7. Relatório Final

# %% [markdown]
# O objetivo do relatório é propor a melhor opção para a venda de uma das quatro lojas, utilizando os dados obtidos e as análises dos gráficos gerados, além da avaliação de alguns critérios como faturamento, categorias de produtos, vendas, avaliações e valores de frete.
#
#
# <br>
#
# **1. Análise de Faturamento (R$)**
#
# - **Loja 1** - 1.534.509,12
# - **Loja 2** - 1.488.459,06
# - **Loja 3** - 1.464.025,03
# - **Loja 4** - 1.384.497,58
#
# A Loja 4 tem o pior desempenho financeiro entre as quatro lojas.
#
# <br>
#
# ---
#
# <br>
#
#   **2. Categorias Mais e Menos Vendidas**
#
# Em todas as lojas, as categorias de móveis, eletrônicos e brinquedos se destacam como as mais vendidas.
#
# A estrutura de vendas por categoria é semelhante entre todas as lojas.
#
# <br>
#
# ---
#
# <br>
#
# **3. Avaliação Média dos Clientes**
#
# As avaliações médias foram bem próximas:
#
# - **Loja 1** - 3,98
# - **Loja 2** - 4,04
# - **Loja 3** - 4,05
# - **Loja 4** - 4,00
#
# As quatro lojas têm boa reputação, a Loja 3 se destaca levemente, enquanto a Loja 1 tem a menor média geral.
#
# <br>
#
# ---
#
# <br>
#
# **4. Produtos Mais e Menos Vendidos**
#
# Cada loja possui uma combinação distinta entre os produtos mais e menos vendidos.
#
# <br>
#
# ---
#
# <br>
#
# **5. Frete Médio (R$)**
#
# - **Loja 1** - 34,69
# - **Loja 2** - 33,62
# - **Loja 3** - 33,07
# - **Loja 4** - 31,28
#
# A Loja 4 tem o valor de frete médio mais baixo, o que indica boa eficiência logística, mas não define um melhor desempenho financeiro.
#
# <br>
#
# ---
#
# <br>
#
# **6. Conclusão**
#
# Com base nos fatores analisados (faturamento, vendas por categorias e produtos, avaliações e frete) a Loja 4 é a opção mais indicada para ser vendida.
#
# Apesar de apresentar o menor valor médio de frete, o que indica uma operação logística eficiente, e uma boa média de avaliação, seu resultado financeiro demonstra um desempenho abaixo das demais unidades, visto que seu faturamento total é o mais baixo entre as quatro lojas.
#
# Considerando que cada loja possui um perfil de vendas distinto, a decisão deve se basear em indicadores de faturamento e eficiência operacional. Sob essa ótica, a Loja 4 é a melhor opção para venda, permitindo até mesmo realocar recursos e concentrar investimentos nas lojas com melhor desempenho financeiro.
